# %% [markdown]
# ## Initial Imports

# %%
import tensorflow
import numpy as np
import keras
import cv2,os

# %%
#Unzip
import zipfile
zip_path = "/content/archive (6).zip"
extract_path = "/content/extracted_folder"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %% [markdown]
# ## DATA PREPROCESSING

# %%
data_path='/content/extracted_folder/Training'
categories=sorted(os.listdir(data_path))
labels=[i for i in range(len(categories))]

label_dict=dict(zip(categories,labels)) #empty dictionary
print(label_dict)
print(categories)
print(labels)
# Out:
# {'0Normal': 0, '1Doubtful': 1, '2Mild': 2, '3Moderate': 3, '4Severe': 4}
# ['0Normal', '1Doubtful', '2Mild', '3Moderate', '4Severe']
# [0, 1, 2, 3, 4]

# %%
img_size=256
data=[]
label=[]

for category in categories:
    folder_path=os.path.join(data_path,category)
    img_names=os.listdir(folder_path)

    for img_name in img_names:
        img_path=os.path.join(folder_path,img_name)
        img=cv2.imread(img_path)
        try:
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            resized=cv2.resize(gray,(img_size,img_size))
            #resizing the image  into 256 x 256, since we need a fixed common size for all the images in the dataset
            data.append(resized)
            label.append(label_dict[category])
            #appending the image and the label(categorized) into the list (dataset)
        except Exception as e:
            print('Exception:',e)
            #if any exception rasied, the exception will be printed here. And pass to the next image

# %% [markdown]
# ## Rescale and assign catagorical labels

# %%
data=np.array(data)/255.0
data=np.reshape(data,(data.shape[0],img_size,img_size,1))
label=np.array(label)

from keras.utils import to_categorical
new_label= to_categorical(label)

# %%
new_label.shape
# Out:
# (1650, 5)

# %%
data.shape
# Out:
# (1650, 256, 256, 1)

# %%
data.shape[1:]
# Out:
# (256, 256, 1)

# %% [markdown]
# ## Model Creation

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten,Dropout
from keras.layers import Conv2D,MaxPooling2D
from keras.callbacks import ModelCheckpoint

model=Sequential()

model.add(Conv2D(128,(3,3),input_shape=data.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
#The first CNN layer followed by Relu and MaxPooling layers

model.add(Conv2D(64,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
#The second convolution layer followed by Relu and MaxPooling layers

model.add(Conv2D(32,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
#The thrid convolution layer followed by Relu and MaxPooling layers

model.add(Flatten())
#Flatten layer to stack the output convolutions from 3rd convolution layer
model.add(Dropout(0.2))

model.add(Dense(128,activation='relu'))
#Dense layer of 128 neurons

model.add(Dropout(0.1))
model.add(Dense(64,activation='relu'))
#Dense layer of 64 neurons

model.add(Dense(5,activation='softmax'))
#The Final layer with two outputs for two categories

model.compile(loss='categorical_crossentropy',optimizer='Nadam',metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ## Model Summary

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 254, 254, 128)       │           1,280 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 254, 254, 128)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 127, 127, 128)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 125, 125, 64)        │          73,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 125, 125, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 62, 62, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 60, 60, 32)          │          18,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 60, 60, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 30, 30, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 28800)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 28800)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       3,686,528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 5)                   │             325 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,788,645 (14.45 MB)
#  Trainable params: 3,788,645 (14.45 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Splitting data into traning and testing

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(data,new_label,test_size=0.1)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
for i in range(20):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(np.squeeze(x_test[i]))
    plt.xlabel(categories[np.argmax(y_test[i])])
plt.show()

# %% [markdown]
# ## Model Training

# %%
history=model.fit(x_train,y_train,epochs=50,validation_split=0.2)
# Out:
# Epoch 1/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 28s 360ms/step - accuracy: 0.2880 - loss: 1.5805 - val_accuracy: 0.2727 - val_loss: 1.5181
# Epoch 2/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.3126 - loss: 1.5175 - val_accuracy: 0.3468 - val_loss: 1.4862
# Epoch 3/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.3555 - loss: 1.4886 - val_accuracy: 0.3535 - val_loss: 1.4450
# Epoch 4/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - accuracy: 0.3945 - loss: 1.4293 - val_accuracy: 0.3266 - val_loss: 1.4751
# Epoch 5/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.3365 - loss: 1.4496 - val_accuracy: 0.3502 - val_loss: 1.3977
# Epoch 6/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.4242 - loss: 1.3685 - val_accuracy: 0.3872 - val_loss: 1.3823
# Epoch 7/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.4483 - loss: 1.3190 - val_accuracy: 0.3603 - val_loss: 1.4523
# Epoch 8/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.4031 - loss: 1.3593 - val_accuracy: 0.4545 - val_loss: 1.3593
# Epoch 9/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.4450 - loss: 1.2901 - val_accuracy: 0.3603 - val_loss: 1.4452
# Epoch 10/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.4625 - loss: 1.2652 - val_accuracy: 0.4747 - val_loss: 1.2801
# Epoch 11/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.5001 - loss: 1.1953 - val_accuracy: 0.4983 - val_loss: 1.2813
# Epoch 12/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.5395 - loss: 1.1405 - val_accuracy: 0.3973 - val_loss: 1.4903
# Epoch 13/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.5889 - loss: 1.0192 - val_accuracy: 0.4478 - val_loss: 1.2908
# Epoch 14/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.6123 - loss: 0.9719 - val_accuracy: 0.4815 - val_loss: 1.2792
# Epoch 15/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.6431 - loss: 0.8757 - val_accuracy: 0.5118 - val_loss: 1.2756
# Epoch 16/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.7065 - loss: 0.7507 - val_accuracy: 0.5185 - val_loss: 1.3225
# Epoch 17/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.7253 - loss: 0.6827 - val_accuracy: 0.5522 - val_loss: 1.3699
# Epoch 18/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.7749 - loss: 0.6018 - val_accuracy: 0.5017 - val_loss: 1.6094
# Epoch 19/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.7954 - loss: 0.5401 - val_accuracy: 0.5589 - val_loss: 1.4247
# Epoch 20/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.8376 - loss: 0.4707 - val_accuracy: 0.5556 - val_loss: 1.5281
# Epoch 21/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.8846 - loss: 0.3176 - val_accuracy: 0.5589 - val_loss: 1.5686
# Epoch 22/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.8747 - loss: 0.3134 - val_accuracy: 0.5657 - val_loss: 1.7081
# Epoch 23/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.9298 - loss: 0.2185 - val_accuracy: 0.5589 - val_loss: 1.8150
# Epoch 24/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.9125 - loss: 0.2311 - val_accuracy: 0.5926 - val_loss: 1.9971
# Epoch 25/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.9299 - loss: 0.1890 - val_accuracy: 0.5791 - val_loss: 1.9849
# Epoch 26/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.9389 - loss: 0.1677 - val_accuracy: 0.5724 - val_loss: 2.0642
# Epoch 27/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.9248 - loss: 0.2363 - val_accuracy: 0.5488 - val_loss: 1.8776
# Epoch 28/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.9526 - loss: 0.1660 - val_accuracy: 0.5892 - val_loss: 1.9347
# Epoch 29/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.9535 - loss: 0.1410 - val_accuracy: 0.5791 - val_loss: 2.4516
# Epoch 30/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.9499 - loss: 0.1470 - val_accuracy: 0.5724 - val_loss: 2.0329
# Epoch 31/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.9625 - loss: 0.1084 - val_accuracy: 0.5522 - val_loss: 2.2840
# Epoch 32/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - accuracy: 0.9620 - loss: 0.1098 - val_accuracy: 0.5724 - val_loss: 2.5089
# Epoch 33/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.9426 - loss: 0.1273 - val_accuracy: 0.5556 - val_loss: 2.0746
# Epoch 34/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.9632 - loss: 0.1076 - val_accuracy: 0.5589 - val_loss: 2.2910
# Epoch 35/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.9518 - loss: 0.1287 - val_accuracy: 0.5859 - val_loss: 2.3045
# Epoch 36/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.9672 - loss: 0.1055 - val_accuracy: 0.5690 - val_loss: 2.1918
# Epoch 37/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.9814 - loss: 0.0620 - val_accuracy: 0.5926 - val_loss: 2.2897
# Epoch 38/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.9794 - loss: 0.0584 - val_accuracy: 0.5859 - val_loss: 2.3223
# Epoch 39/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.9716 - loss: 0.0786 - val_accuracy: 0.5657 - val_loss: 2.4847
# Epoch 40/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.9791 - loss: 0.0661 - val_accuracy: 0.5522 - val_loss: 2.5202
# Epoch 41/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.9455 - loss: 0.1403 - val_accuracy: 0.5488 - val_loss: 2.4978
# Epoch 42/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.9792 - loss: 0.0600 - val_accuracy: 0.5791 - val_loss: 2.5263
# Epoch 43/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.9784 - loss: 0.0552 - val_accuracy: 0.5488 - val_loss: 2.5004
# Epoch 44/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.9797 - loss: 0.0545 - val_accuracy: 0.5791 - val_loss: 2.5942
# Epoch 45/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.9855 - loss: 0.0538 - val_accuracy: 0.5522 - val_loss: 2.7288
# Epoch 46/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.9835 - loss: 0.0507 - val_accuracy: 0.5589 - val_loss: 2.8484
# Epoch 47/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.9848 - loss: 0.0444 - val_accuracy: 0.5859 - val_loss: 2.9062
# Epoch 48/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.9892 - loss: 0.0331 - val_accuracy: 0.5657 - val_loss: 2.7030
# Epoch 49/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.9830 - loss: 0.0476 - val_accuracy: 0.5219 - val_loss: 2.7078
# Epoch 50/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.9600 - loss: 0.1069 - val_accuracy: 0.5758 - val_loss: 2.5885

# %% [markdown]
# ## Export The Model

# %%
model.save('1st model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## Plot The Training Loss And Accuracy

# %%
from matplotlib import pyplot as plt

# %%
N = len(history.history["loss"])
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), history.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), history.history["val_accuracy"], label="val_acc")
plt.title("Training Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Accuracy")
plt.legend(loc="center right")
plt.savefig("CNN_Model")

# %%
# Get the actual number of epochs from the history object
N = len(history.history["loss"])  # This will get the correct length based on training

plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), history.history["val_loss"], label="val_loss")

plt.title("Training Loss")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend(loc="center right")
plt.savefig("CNN_Model")

# %% [markdown]
# ## Accuracy

# %%
vaL_loss, val_accuracy= model.evaluate(x_test, y_test, verbose=0)
print("test loss:", vaL_loss,'%')
print("test accuracy:", val_accuracy,"%")
# Out:
# test loss: 3.3701982498168945 %
# test accuracy: 0.5151515007019043 %

# %% [markdown]
# ## Prediction

# %%
X = 32

img_size = 256

img_single = x_test[X]
img_single = cv2.resize(img_single, (img_size, img_size))
img_single = (np.expand_dims(img_single, 0))
img_single = img_single.reshape(img_single.shape[0],256,256,1)

predictions_single = model.predict(img_single)
print('A.I predicts:',categories[np.argmax(predictions_single)])
print("Correct prediction for label",np.argmax(y_test[X]),'is',categories[np.argmax(y_test[X])])
plt.imshow(np.squeeze(img_single))
plt.grid(False)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 752ms/step
# A.I predicts: 2Mild
# Correct prediction for label 0 is 0Normal

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
from mlxtend.plotting import plot_confusion_matrix

test_labels = np.argmax(y_test, axis=1)
predictions = model.predict(x_test)
predictions = np.argmax(predictions, axis=-1)


cm  = confusion_matrix(test_labels, predictions)
plt.figure()
plot_confusion_matrix(cm,figsize=(12,8), hide_ticks=True,cmap=plt.cm.Blues)
plt.xticks(range(5), ['Normal','Doubtful','Mild','Moderate','Severe'], fontsize=16)
plt.yticks(range(5), ['Normal','Doubtful','Mild','Moderate','Severe'], fontsize=16)
plt.show()
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
